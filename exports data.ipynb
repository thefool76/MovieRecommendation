# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Arun Kumar\Documents\spices\country_wise.csv")

# %%
df
# Out:
#        Year      Country       QTY     VALUE
# 0   2015-16        U.S.A  10740.47  65961.15
# 1   2015-16          U.K   2122.38  14599.25
# 2   2015-16      GERMANY   1961.90  11375.07
# 3   2015-16       SWEDEN    627.25   4577.97
# 4   2015-16        JAPAN    697.47   5086.22
# 5   2015-16       CANADA    581.95   3621.98
# 6   2015-16     THAILAND      1.02      7.17
# 7   2015-16        ITALY    549.57   3274.78
# 8   2015-16       FRANCE    330.82   2579.75
# 9   2015-16  NETHERLANDS   1171.44   7592.08
# 10  2015-16    AUSTRALIA    465.10   3264.00
# 11  2015-16      ESTONIA    131.11    954.69
# 12  2015-16     MALAYSIA     72.75    523.64
# 13  2015-16        U.A.E    598.93   3594.91
# 14  2015-16  PHILLIPINES    143.43    834.74
# 15  2016-17        U.S.A   8128.17  52679.79
# 16  2016-17          U.K   1868.25  11738.01
# 17  2016-17      GERMANY    972.30   7905.81
# 18  2016-17       SWEDEN   1034.10   7804.79
# 19  2016-17        JAPAN    746.71   5418.25
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'QTY', 'VALUE'], dtype='object')

# %%
#plt.figure(figsize=(45,35))
sns.catplot(x="Country",y="QTY",kind='bar',hue='Year',data=df,height=7,aspect=2.5)
plt.title("COUNTRY-WISE EXPORT OF Black Pepper FROM INDIA (QTY IN M.T; VALUE IN RS.LAKHS)")
# Out:
# Text(0.5, 1.0, 'COUNTRY-WISE EXPORT OF Black Pepper FROM INDIA (QTY IN M.T; VALUE IN RS.LAKHS)')

# %%
df1=pd.read_csv(r"C:\Users\Arun Kumar\Documents\spices\year wise data.csv")

# %%
df1
# Out:
#        Year                    Item       QTY     Values  Rate(rs/kg)
# 0   2019-20                  CHILLI  484000.0  622170.00       128.55
# 1   2019-20        MINT PRODUCTS(3)   22725.0  383835.00      1689.04
# 2   2019-20                   CUMIN  210000.0  322500.00       153.57
# 3   2019-20  SPICE OILS &OLEORESINS   13950.0  264525.00      1896.24
# 4   2019-20                TURMERIC  136000.0  121640.00        89.44
# 5   2019-20     CURRY POWDERS/PASTE   38200.0   83410.00       218.35
# 6   2019-20         OTHER SPICES(2)   41050.0   66303.00       161.52
# 7   2019-20                  PEPPER   16250.0   55187.00       339.61
# 8   2019-20                  GINGER   50410.0   44905.00        89.08
# 9   2019-20             CARDAMOM(S)    2090.0   42629.50      2039.69
# 10  2019-20               CORIANDER   50250.0   41110.00        81.81
# 11  2019-20                  FENNEL   23800.0   22888.00        96.17
# ...

# %%
df1.columns
# Out:
# Index(['Year', 'Item', 'QTY', 'Values', 'Rate(rs/kg)'], dtype='object')

# %%
plt.figure(figsize=(25,10))
ax = sns.barplot(x="Item", y="QTY",hue="Year", data=df1)
plt.title("ESTIMATED EXPORT OF SPICES FROM INDIA DURING APRIL - MARCH 2019-20 COMPARED WITH APRIL - MARCH 2018-19")
ax.figure.savefig(r"C:\Users\Arun Kumar\Documents\spices\output.png")
